# %%
import cv2
from image_augmentation_scripts import *
import matplotlib.pyplot as plt
import os

# %%
os.chdir(r"C:\Users\15404\Documents\GitHub\RiceDiseaseDetection\rice_data\original_images\_Healthy")

# %%
img1 = cv2.imread("shape22.jpg")

# %%
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1_rgb)

# %%
def flip_image(image):
