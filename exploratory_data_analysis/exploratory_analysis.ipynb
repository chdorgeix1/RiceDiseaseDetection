# %%
import shutil
import os
import glob
import random
import cv2
import matplotlib.pyplot as plt
from analysis_scripts import *

# %% [markdown]
# ### Demonstrate Similar Brightness Distributions Between Val and Test Sets

# %%
val_dir = r'C:\Users\15404\Documents\GitHub\RiceDiseaseDetection\rice_data\validation_images\\'
test_dir = r'C:\Users\15404\Documents\GitHub\RiceDiseaseDetection\rice_data\test_images\\'
img_dir = ['_Brownspot', '_Healthy', '_Hispa', '_LeafBlast']

# %%
for img_type in img_dir:
    print(img_type)
    print('Validation Brightness Distribution:')
    img_list, bright_list = brightness_hist_for_img_folder(val_dir + img_type)
    show_bright_and_dim_imgs1(bright_list, img_list)
    print('Test Brightness Distribution:')
    img_list, bright_list = brightness_hist_for_img_folder(test_dir + img_type)
    show_bright_and_dim_imgs1(bright_list, img_list)
    print('')
    print('')
    print('')
# Out:
# _Brownspot
# Validation Brightness Distribution:
# Test Brightness Distribution:
# _Healthy
# Validation Brightness Distribution:
# Test Brightness Distribution:
# _Hispa
# Validation Brightness Distribution:
# Test Brightness Distribution:
# _LeafBlast
# Validation Brightness Distribution:
# Test Brightness Distribution:
